# %%
import imgaug.augmenters as iaa
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2

# %%
image_name = '/Users/HemingY/Documents/brain_classification/data/mouse_brain_challenge/coronal/0-0-0 - 2019-08-07T142609.838.jpg'
image = cv2.imread(image_name)[:,:,::-1]
max_value = np.max(image)
plt.imshow(image)

# %%
seq = iaa.Sequential([
        # iaa.Sometimes(
        #     0,
        # iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*max_value), per_channel=0.5)),
            
        # iaa.Sometimes(
        #     0,
        #     iaa.GaussianBlur(sigma=(1))
        # ),

        #iaa.flip.Fliplr(p=0.5),

        iaa.Sometimes(
            0.5,
            iaa.Affine(rotate=(-30, 30),
            cval=250)
        ),
        # iaa.Sometimes(
        #     0.5,
        #     iaa.ShearX((-10, 10))
        # ),

        ], random_order=True)

newarrayimage = seq(image=image)
plt.figure(figsize=(12,12))
plt.imshow(newarrayimage)
